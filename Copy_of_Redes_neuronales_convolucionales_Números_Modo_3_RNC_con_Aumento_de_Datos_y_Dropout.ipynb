# %% [markdown]
# <a href="https://colab.research.google.com/github/ESPE-KLCarvajalA/Distribuidora_GestionDeBodegas/blob/main/Copy_of_Redes_neuronales_convolucionales_N%C3%BAmeros_Modo_3_RNC_con_Aumento_de_Datos_y_Dropout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Este colab forma parte del video de Redes Neuronales Convolucionales del canal de Youtube "Ringa Tech"
# https://youtu.be/eGDSlW93Bng
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import numpy as np
from tensorflow.keras.utils import to_categorical

#Cargar los datos de MNIST
#Aqui lo hago de otra manera porque es mas simple para poder usar el modulo de aumento de datos
#de Keras de esta manera
(X_entrenamiento, Y_entrenamiento), (X_pruebas, Y_pruebas) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
#Colocar los datos en la forma correcta que ya hemos visto (1, 28, 28, 1)
X_entrenamiento = X_entrenamiento.reshape(X_entrenamiento.shape[0], 28, 28, 1)
X_pruebas = X_pruebas.reshape(X_pruebas.shape[0], 28, 28, 1)

#Hacer 'one-hot encoding' de los resultados (e.g. en lugar de tener como resultado una sola neurona, tendre 10 donde solo el resultado correcto sera 1 y el resto 0)
Y_entrenamiento = to_categorical(Y_entrenamiento)
Y_pruebas = to_categorical(Y_pruebas)

#Convertir a flotante y normalizar para que aprenda mejor la red
X_entrenamiento = X_entrenamiento.astype('float32') / 255
X_pruebas = X_pruebas.astype('float32') / 255

# %%
#Codigo para mostrar imagenes del set, no es necesario ejecutarlo, solo imprime unos numeros :)
import matplotlib.pyplot as plt
filas = 2
columnas = 8
num = filas*columnas
imagenes = X_entrenamiento[0:num]
etiquetas = Y_entrenamiento[0:num]
fig, axes = plt.subplots(filas, columnas, figsize=(1.5*columnas,2*filas))
for i in range(num):
     ax = axes[i//columnas, i%columnas]
     ax.imshow(imagenes[i].reshape(28,28), cmap='gray_r')
     ax.set_title('Label: {}'.format(np.argmax(etiquetas[i])))
plt.tight_layout()
plt.show()

# %%
#Aumento de datos
#Variables para controlar las transformaciones que se haran en el aumento de datos
#utilizando ImageDataGenerator de keras

from tensorflow.keras.preprocessing.image import ImageDataGenerator

rango_rotacion = 30
mov_ancho = 0.25
mov_alto = 0.25
#rango_inclinacion=15 #No uso este de momento pero si quieres puedes probar usandolo!
rango_acercamiento=[0.5,1.5]

datagen = ImageDataGenerator(
    rotation_range = rango_rotacion,
    width_shift_range = mov_ancho,
    height_shift_range = mov_alto,
    zoom_range=rango_acercamiento,
    #shear_range=rango_inclinacion #No uso este de momento pero si quieres puedes probar usandolo!
)

datagen.fit(X_entrenamiento)

# %%
#Codigo para mostrar imagenes del set, no es necesario ejecutarlo, solo imprime como se ven antes y despues de las transformaciones
filas = 4
columnas = 8
num = filas*columnas
print('ANTES:\n')
fig1, axes1 = plt.subplots(filas, columnas, figsize=(1.5*columnas,2*filas))
for i in range(num):
     ax = axes1[i//columnas, i%columnas]
     ax.imshow(X_entrenamiento[i].reshape(28,28), cmap='gray_r')
     ax.set_title('Label: {}'.format(np.argmax(Y_entrenamiento[i])))
plt.tight_layout()
plt.show()
print('DESPUES:\n')
fig2, axes2 = plt.subplots(filas, columnas, figsize=(1.5*columnas,2*filas))
for X, Y in datagen.flow(X_entrenamiento,Y_entrenamiento.reshape(Y_entrenamiento.shape[0], 10),batch_size=num,shuffle=False):
     for i in range(0, num):
          ax = axes2[i//columnas, i%columnas]
          ax.imshow(X[i].reshape(28,28), cmap='gray_r')
          ax.set_title('Label: {}'.format(int(np.argmax(Y[i]))))
     break
plt.tight_layout()
plt.show()
# Out:
# ANTES:
# DESPUES:

# %%
#Modelo!
modelo = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(10, activation="softmax")
])

#Compilación
modelo.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
#Los datos para entrenar saldran del datagen, de manera que sean generados con las transformaciones que indicamos
data_gen_entrenamiento = datagen.flow(X_entrenamiento, Y_entrenamiento, batch_size=32)

# %%
TAMANO_LOTE = 32

#Entrenar la red. Toma un buen rato! Ve por un café ;)
#Oye suscribete al canal!
print("Entrenando modelo...");
epocas=200
history = modelo.fit(
    data_gen_entrenamiento,
    epochs=epocas,
    batch_size=TAMANO_LOTE,
    validation_data=(X_pruebas, Y_pruebas),
    steps_per_epoch=int(np.ceil(60000 / float(TAMANO_LOTE))),
    validation_steps=int(np.ceil(10000 / float(TAMANO_LOTE)))
)

print("Modelo entrenado!");
# Out:
# Entrenando modelo...
# Epoch 1/200
# 1875/1875 [==============================] - 31s 14ms/step - loss: 1.1928 - accuracy: 0.5973 - val_loss: 0.1839 - val_accuracy: 0.9500
# Epoch 2/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.7000 - accuracy: 0.7743 - val_loss: 0.1235 - val_accuracy: 0.9653
# Epoch 3/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.5887 - accuracy: 0.8088 - val_loss: 0.1240 - val_accuracy: 0.9648
# Epoch 4/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.5255 - accuracy: 0.8307 - val_loss: 0.0930 - val_accuracy: 0.9704
# Epoch 5/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.4767 - accuracy: 0.8458 - val_loss: 0.0729 - val_accuracy: 0.9773
# Epoch 6/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.4603 - accuracy: 0.8526 - val_loss: 0.0735 - val_accuracy: 0.9751
# Epoch 7/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.4365 - accuracy: 0.8603 - val_loss: 0.0774 - val_accuracy: 0.9765
# Epoch 8/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.4174 - accuracy: 0.8640 - val_loss: 0.0670 - val_accuracy: 0.9784
# Epoch 9/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.4066 - accuracy: 0.8689 - val_loss: 0.0613 - val_accuracy: 0.9794
# Epoch 10/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3995 - accuracy: 0.8715 - val_loss: 0.0537 - val_accuracy: 0.9830
# Epoch 11/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3816 - accuracy: 0.8771 - val_loss: 0.0460 - val_accuracy: 0.9842
# Epoch 12/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3798 - accuracy: 0.8764 - val_loss: 0.0700 - val_accuracy: 0.9763
# Epoch 13/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3661 - accuracy: 0.8821 - val_loss: 0.0567 - val_accuracy: 0.9821
# Epoch 14/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3566 - accuracy: 0.8843 - val_loss: 0.0528 - val_accuracy: 0.9834
# Epoch 15/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3557 - accuracy: 0.8841 - val_loss: 0.0504 - val_accuracy: 0.9834
# Epoch 16/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3437 - accuracy: 0.8896 - val_loss: 0.0746 - val_accuracy: 0.9749
# Epoch 17/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3433 - accuracy: 0.8899 - val_loss: 0.0624 - val_accuracy: 0.9802
# Epoch 18/200
# 1875/1875 [==============================] - 25s 14ms/step - loss: 0.3423 - accuracy: 0.8895 - val_loss: 0.0496 - val_accuracy: 0.9822
# Epoch 19/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3357 - accuracy: 0.8915 - val_loss: 0.0502 - val_accuracy: 0.9836
# Epoch 20/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3345 - accuracy: 0.8937 - val_loss: 0.0686 - val_accuracy: 0.9780
# Epoch 21/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3272 - accuracy: 0.8945 - val_loss: 0.0483 - val_accuracy: 0.9849
# Epoch 22/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3234 - accuracy: 0.8954 - val_loss: 0.0643 - val_accuracy: 0.9794
# Epoch 23/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3261 - accuracy: 0.8956 - val_loss: 0.0501 - val_accuracy: 0.9841
# Epoch 24/200
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.3235 - accuracy: 0.8950 - val_loss: 0.0657 - val_accuracy: 0.9783
# Epoch 25/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3173 - accuracy: 0.8986 - val_loss: 0.0529 - val_accuracy: 0.9822
# Epoch 26/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3144 - accuracy: 0.9001 - val_loss: 0.0673 - val_accuracy: 0.9794
# Epoch 27/200
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.3152 - accuracy: 0.8984 - val_loss: 0.0556 - val_accuracy: 0.9829
# Epoch 28/200
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.3114 - accuracy: 0.8999 - val_loss: 0.0592 - val_accuracy: 0.9815
# Epoch 29/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3032 - accuracy: 0.9013 - val_loss: 0.0450 - val_accuracy: 0.9855
# Epoch 30/200
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.3050 - accuracy: 0.9005 - val_loss: 0.0605 - val_accuracy: 0.9797
# Epoch 31/200
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.2986 - accuracy: 0.9028 - val_loss: 0.0552 - val_accuracy: 0.9827
# Epoch 32/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3054 - accuracy: 0.9012 - val_loss: 0.0529 - val_accuracy: 0.9827
# Epoch 33/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3047 - accuracy: 0.9018 - val_loss: 0.0522 - val_accuracy: 0.9828
# Epoch 34/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3020 - accuracy: 0.9024 - val_loss: 0.0575 - val_accuracy: 0.9820
# Epoch 35/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2953 - accuracy: 0.9051 - val_loss: 0.0589 - val_accuracy: 0.9803
# Epoch 36/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2944 - accuracy: 0.9052 - val_loss: 0.0579 - val_accuracy: 0.9813
# Epoch 37/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2926 - accuracy: 0.9062 - val_loss: 0.0655 - val_accuracy: 0.9791
# Epoch 38/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2928 - accuracy: 0.9070 - val_loss: 0.0502 - val_accuracy: 0.9842
# Epoch 39/200
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.2903 - accuracy: 0.9065 - val_loss: 0.0489 - val_accuracy: 0.9846
# Epoch 40/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2959 - accuracy: 0.9047 - val_loss: 0.0533 - val_accuracy: 0.9826
# Epoch 41/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2895 - accuracy: 0.9065 - val_loss: 0.0551 - val_accuracy: 0.9820
# Epoch 42/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2834 - accuracy: 0.9092 - val_loss: 0.0637 - val_accuracy: 0.9801
# Epoch 43/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2861 - accuracy: 0.9070 - val_loss: 0.0502 - val_accuracy: 0.9833
# Epoch 44/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2889 - accuracy: 0.9071 - val_loss: 0.0556 - val_accuracy: 0.9809
# Epoch 45/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2774 - accuracy: 0.9110 - val_loss: 0.0519 - val_accuracy: 0.9836
# Epoch 46/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2813 - accuracy: 0.9092 - val_loss: 0.0554 - val_accuracy: 0.9828
# Epoch 47/200
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2828 - accuracy: 0.9087 - val_loss: 0.0539 - val_accuracy: 0.9832
# Epoch 48/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2793 - accuracy: 0.9100 - val_loss: 0.0420 - val_accuracy: 0.9862
# Epoch 49/200
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.2785 - accuracy: 0.9099 - val_loss: 0.0485 - val_accuracy: 0.9837
# Epoch 50/200
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.2839 - accuracy: 0.9082 - val_loss: 0.0389 - val_accuracy: 0.9854
# Epoch 51/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2795 - accuracy: 0.9099 - val_loss: 0.0513 - val_accuracy: 0.9824
# Epoch 52/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2767 - accuracy: 0.9112 - val_loss: 0.0442 - val_accuracy: 0.9849
# Epoch 53/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2826 - accuracy: 0.9097 - val_loss: 0.0577 - val_accuracy: 0.9814
# Epoch 54/200
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2824 - accuracy: 0.9094 - val_loss: 0.0415 - val_accuracy: 0.9869
# Epoch 55/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2792 - accuracy: 0.9105 - val_loss: 0.0463 - val_accuracy: 0.9849
# Epoch 56/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2718 - accuracy: 0.9133 - val_loss: 0.0486 - val_accuracy: 0.9842
# Epoch 57/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2744 - accuracy: 0.9111 - val_loss: 0.0542 - val_accuracy: 0.9838
# Epoch 58/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2732 - accuracy: 0.9120 - val_loss: 0.0558 - val_accuracy: 0.9830
# Epoch 59/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2779 - accuracy: 0.9097 - val_loss: 0.0433 - val_accuracy: 0.9859
# Epoch 60/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2799 - accuracy: 0.9103 - val_loss: 0.0489 - val_accuracy: 0.9837
# Epoch 61/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2739 - accuracy: 0.9120 - val_loss: 0.0434 - val_accuracy: 0.9856
# Epoch 62/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2722 - accuracy: 0.9128 - val_loss: 0.0454 - val_accuracy: 0.9858
# Epoch 63/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2702 - accuracy: 0.9126 - val_loss: 0.0471 - val_accuracy: 0.9851
# Epoch 64/200
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2717 - accuracy: 0.9136 - val_loss: 0.0510 - val_accuracy: 0.9837
# Epoch 65/200
# 1875/1875 [==============================] - 25s 14ms/step - loss: 0.2755 - accuracy: 0.9106 - val_loss: 0.0482 - val_accuracy: 0.9850
# Epoch 66/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2714 - accuracy: 0.9122 - val_loss: 0.0587 - val_accuracy: 0.9816
# Epoch 67/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2721 - accuracy: 0.9141 - val_loss: 0.0427 - val_accuracy: 0.9858
# Epoch 68/200
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2697 - accuracy: 0.9135 - val_loss: 0.0489 - val_accuracy: 0.9834
# Epoch 69/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2651 - accuracy: 0.9158 - val_loss: 0.0471 - val_accuracy: 0.9850
# Epoch 70/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2715 - accuracy: 0.9140 - val_loss: 0.0431 - val_accuracy: 0.9863
# Epoch 71/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2713 - accuracy: 0.9125 - val_loss: 0.0457 - val_accuracy: 0.9859
# Epoch 72/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2615 - accuracy: 0.9165 - val_loss: 0.0472 - val_accuracy: 0.9838
# Epoch 73/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2672 - accuracy: 0.9133 - val_loss: 0.0565 - val_accuracy: 0.9821
# Epoch 74/200
# 1875/1875 [==============================] - 25s 14ms/step - loss: 0.2610 - accuracy: 0.9165 - val_loss: 0.0445 - val_accuracy: 0.9851
# Epoch 75/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2629 - accuracy: 0.9151 - val_loss: 0.0450 - val_accuracy: 0.9847
# Epoch 76/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2651 - accuracy: 0.9153 - val_loss: 0.0515 - val_accuracy: 0.9837
# Epoch 77/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2640 - accuracy: 0.9148 - val_loss: 0.0459 - val_accuracy: 0.9849
# Epoch 78/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2651 - accuracy: 0.9149 - val_loss: 0.0428 - val_accuracy: 0.9865
# Epoch 79/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2667 - accuracy: 0.9136 - val_loss: 0.0560 - val_accuracy: 0.9820
# Epoch 80/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2602 - accuracy: 0.9153 - val_loss: 0.0530 - val_accuracy: 0.9835
# Epoch 81/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2645 - accuracy: 0.9147 - val_loss: 0.0735 - val_accuracy: 0.9784
# Epoch 82/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2631 - accuracy: 0.9168 - val_loss: 0.0529 - val_accuracy: 0.9836
# Epoch 83/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2624 - accuracy: 0.9157 - val_loss: 0.0537 - val_accuracy: 0.9837
# Epoch 84/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2581 - accuracy: 0.9163 - val_loss: 0.0487 - val_accuracy: 0.9846
# Epoch 85/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2605 - accuracy: 0.9162 - val_loss: 0.0449 - val_accuracy: 0.9848
# Epoch 86/200
# 1875/1875 [==============================] - 25s 14ms/step - loss: 0.2661 - accuracy: 0.9142 - val_loss: 0.0516 - val_accuracy: 0.9836
# Epoch 87/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2623 - accuracy: 0.9154 - val_loss: 0.0515 - val_accuracy: 0.9849
# Epoch 88/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2563 - accuracy: 0.9178 - val_loss: 0.0432 - val_accuracy: 0.9860
# Epoch 89/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2665 - accuracy: 0.9150 - val_loss: 0.0495 - val_accuracy: 0.9829
# Epoch 90/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2582 - accuracy: 0.9172 - val_loss: 0.0527 - val_accuracy: 0.9840
# Epoch 91/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2584 - accuracy: 0.9173 - val_loss: 0.0550 - val_accuracy: 0.9830
# Epoch 92/200
# 1875/1875 [==============================] - 25s 14ms/step - loss: 0.2621 - accuracy: 0.9172 - val_loss: 0.0520 - val_accuracy: 0.9845
# Epoch 93/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2569 - accuracy: 0.9183 - val_loss: 0.0476 - val_accuracy: 0.9857
# Epoch 94/200
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.2578 - accuracy: 0.9165 - val_loss: 0.0513 - val_accuracy: 0.9849
# Epoch 95/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2551 - accuracy: 0.9188 - val_loss: 0.0491 - val_accuracy: 0.9853
# Epoch 96/200
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2618 - accuracy: 0.9162 - val_loss: 0.0454 - val_accuracy: 0.9860
# Epoch 97/200
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2593 - accuracy: 0.9167 - val_loss: 0.0590 - val_accuracy: 0.9825
# Epoch 98/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2562 - accuracy: 0.9182 - val_loss: 0.0515 - val_accuracy: 0.9835
# Epoch 99/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2545 - accuracy: 0.9180 - val_loss: 0.0520 - val_accuracy: 0.9841
# Epoch 100/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2550 - accuracy: 0.9183 - val_loss: 0.0478 - val_accuracy: 0.9851
# Epoch 101/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2590 - accuracy: 0.9175 - val_loss: 0.0414 - val_accuracy: 0.9866
# Epoch 102/200
# 1875/1875 [==============================] - 25s 14ms/step - loss: 0.2499 - accuracy: 0.9189 - val_loss: 0.0507 - val_accuracy: 0.9841
# Epoch 103/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2565 - accuracy: 0.9171 - val_loss: 0.0535 - val_accuracy: 0.9837
# Epoch 104/200
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.2528 - accuracy: 0.9174 - val_loss: 0.0426 - val_accuracy: 0.9864
# Epoch 105/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2537 - accuracy: 0.9185 - val_loss: 0.0468 - val_accuracy: 0.9841
# Epoch 106/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2583 - accuracy: 0.9168 - val_loss: 0.0483 - val_accuracy: 0.9843
# Epoch 107/200
# 1875/1875 [==============================] - 25s 14ms/step - loss: 0.2503 - accuracy: 0.9198 - val_loss: 0.0480 - val_accuracy: 0.9854
# Epoch 108/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2558 - accuracy: 0.9176 - val_loss: 0.0502 - val_accuracy: 0.9841
# Epoch 109/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2583 - accuracy: 0.9164 - val_loss: 0.0440 - val_accuracy: 0.9856
# Epoch 110/200
# 1875/1875 [==============================] - 25s 14ms/step - loss: 0.2579 - accuracy: 0.9170 - val_loss: 0.0546 - val_accuracy: 0.9825
# Epoch 111/200
# 1875/1875 [==============================] - 25s 14ms/step - loss: 0.2559 - accuracy: 0.9177 - val_loss: 0.0581 - val_accuracy: 0.9837
# Epoch 112/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2558 - accuracy: 0.9172 - val_loss: 0.0522 - val_accuracy: 0.9841
# Epoch 113/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2550 - accuracy: 0.9179 - val_loss: 0.0516 - val_accuracy: 0.9853
# Epoch 114/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2541 - accuracy: 0.9187 - val_loss: 0.0473 - val_accuracy: 0.9858
# Epoch 115/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2478 - accuracy: 0.9215 - val_loss: 0.0465 - val_accuracy: 0.9857
# Epoch 116/200
# 1875/1875 [==============================] - 25s 14ms/step - loss: 0.2522 - accuracy: 0.9197 - val_loss: 0.0442 - val_accuracy: 0.9863
# Epoch 117/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2583 - accuracy: 0.9177 - val_loss: 0.0572 - val_accuracy: 0.9827
# Epoch 118/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2518 - accuracy: 0.9198 - val_loss: 0.0417 - val_accuracy: 0.9873
# Epoch 119/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2507 - accuracy: 0.9187 - val_loss: 0.0523 - val_accuracy: 0.9850
# Epoch 120/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2599 - accuracy: 0.9171 - val_loss: 0.0486 - val_accuracy: 0.9852
# Epoch 121/200
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2566 - accuracy: 0.9176 - val_loss: 0.0569 - val_accuracy: 0.9842
# Epoch 122/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2475 - accuracy: 0.9207 - val_loss: 0.0522 - val_accuracy: 0.9829
# Epoch 123/200
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.2478 - accuracy: 0.9208 - val_loss: 0.0568 - val_accuracy: 0.9830
# Epoch 124/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2519 - accuracy: 0.9196 - val_loss: 0.0381 - val_accuracy: 0.9888
# Epoch 125/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2516 - accuracy: 0.9189 - val_loss: 0.0449 - val_accuracy: 0.9862
# Epoch 126/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2514 - accuracy: 0.9188 - val_loss: 0.0594 - val_accuracy: 0.9818
# Epoch 127/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2525 - accuracy: 0.9183 - val_loss: 0.0477 - val_accuracy: 0.9857
# Epoch 128/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2496 - accuracy: 0.9196 - val_loss: 0.0487 - val_accuracy: 0.9854
# Epoch 129/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2520 - accuracy: 0.9196 - val_loss: 0.0475 - val_accuracy: 0.9858
# Epoch 130/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2466 - accuracy: 0.9209 - val_loss: 0.0424 - val_accuracy: 0.9868
# Epoch 131/200
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2529 - accuracy: 0.9185 - val_loss: 0.0639 - val_accuracy: 0.9811
# Epoch 132/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2506 - accuracy: 0.9199 - val_loss: 0.0402 - val_accuracy: 0.9879
# Epoch 133/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2486 - accuracy: 0.9200 - val_loss: 0.0466 - val_accuracy: 0.9847
# Epoch 134/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2495 - accuracy: 0.9193 - val_loss: 0.0492 - val_accuracy: 0.9860
# Epoch 135/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2503 - accuracy: 0.9206 - val_loss: 0.0421 - val_accuracy: 0.9871
# Epoch 136/200
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2486 - accuracy: 0.9195 - val_loss: 0.0449 - val_accuracy: 0.9862
# Epoch 137/200
# 1875/1875 [==============================] - 25s 14ms/step - loss: 0.2504 - accuracy: 0.9191 - val_loss: 0.0477 - val_accuracy: 0.9848
# Epoch 138/200
# 1875/1875 [==============================] - 25s 14ms/step - loss: 0.2482 - accuracy: 0.9199 - val_loss: 0.0426 - val_accuracy: 0.9865
# Epoch 139/200
# 1875/1875 [==============================] - 25s 14ms/step - loss: 0.2481 - accuracy: 0.9205 - val_loss: 0.0442 - val_accuracy: 0.9863
# Epoch 140/200
#  542/1875 [=======>......................] - ETA: 18s - loss: 0.2501 - accuracy: 0.9179

# %%
#Exportar el modelo al explorador! (Mas detalle de esto en en mi video de exportacion: https://youtu.be/JpE4bYyRADI )
modelo.save('numeros_conv_ad_do.h5')

#Convertirlo a tensorflow.js
# !pip install tensorflowjs

# !mkdir carpeta_salida

# !tensorflowjs_converter --input_format keras numeros_conv_ad_do.h5 carpeta_salida
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5c9609578b06> in <cell line: 2>()
#       1 #Exportar el modelo al explorador! (Mas detalle de esto en en mi video de exportacion: https://youtu.be/JpE4bYyRADI )
# ----> 2 modelo.save('numeros_conv_ad_do.h5')
#       3
#       4 #Convertirlo a tensorflow.js
#       5 get_ipython().system('pip install tensorflowjs')
#
# NameError: name 'modelo' is not defined
